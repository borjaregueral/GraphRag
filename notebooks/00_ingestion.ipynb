# %%
import numpy as np
import pandas as pd

# %%
import pickle

# Path to the pickle file
file_path = "/Users/borja/Documents/Somniumrema/projects/genai/grag/notebooks/chunked_text.pkl"

# Open and read the pickle file
with open(file_path, "rb") as file:
    chunked_text = pickle.load(file)

# Display the contents
chunked_text
# Out:
#                                              post_url post_title  \
# 0             https://www.acquired.fm/episodes/costco     Costco
# 1             https://www.acquired.fm/episodes/costco     Costco
# 2             https://www.acquired.fm/episodes/costco     Costco
# 3             https://www.acquired.fm/episodes/costco     Costco
# 4             https://www.acquired.fm/episodes/costco     Costco
# ...                                               ...        ...
# 2412  https://www.acquired.fm/episodes/episode-19-jet        Jet
# 2413  https://www.acquired.fm/episodes/episode-19-jet        Jet
# 2414  https://www.acquired.fm/episodes/episode-19-jet        Jet
# 2415  https://www.acquired.fm/episodes/episode-19-jet        Jet
# 2416  https://www.acquired.fm/episodes/episode-19-jet        Jet
#
#              series_number        blog_date  \
# 0     Season 13, Episode 2  August 20, 2023
# 1     Season 13, Episode 2  August 20, 2023
# 2     Season 13, Episode 2  August 20, 2023
# ...
